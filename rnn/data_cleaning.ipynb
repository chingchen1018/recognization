# %%
import numpy as np

# %%
train_data = np.load("./trainset.npy")
train_labels = np.load("./trainlabels.npy")
test_data = np.load("./testset.npy")
test_labels = np.load("./testlabel.npy")

# %%
test_labels
# Out:
# array(['0xb6f3', '0xb6f3', '0xb6f3', ..., '0xb7c7', '0xb7c7', '0xb7c7'],
#       dtype='<U6')

# %%
len(test_labels[test_labels == '0xb6f3'])
# Out:
# 84

# %%
len(train_labels[train_labels == '0xb6f4'])
# Out:
# 336

# %%
train_data
# Out:
# array([list([[2, 79, 4, 0, 1, 0], [6, 79, 27, 3, 0, 0], [34, 82, 9, 3, 0, 0], [44, 86, -14, 17, 0, 0], [29, 103, 0, -103, 0, 0], [29, 0, -4, 5, 0, 0], [24, 5, -11, 25, 0, 0], [13, 30, -13, 20, 0, 1], [0, 34, 0, -1, 1, 0], [0, 33, 28, 17, 0, 0], [28, 50, 26, 19, 0, 0], [54, 69, 0, 8, 0, 1], [70, 89, 22, 3, 1, 0], [93, 92, 8, 6, 0, 0], [102, 99, -9, -1, 0, 1], [71, 88, 0, -1, 1, 0], [70, 86, -15, -72, 0, 0], [55, 14, -3, 8, 0, 1], [84, 69, 0, 0, 1, 0], [84, 68, 4, 0, 0, 0], [89, 69, 19, 2, 0, 0], [109, 72, -9, -35, 0, 0], [99, 36, -6, 2, 0, 0], [92, 38, -6, 9, 0, 0], [86, 48, 0, 15, 0, 0], [86, 64, -2, -37, 0, 0], [84, 26, 0, -15, 0, 0], [84, 10, 21, -3, 0, 0], [105, 6, 16, 6, 0, 0], [122, 13, 2, 10, 0, 0], [124, 24, 3, 17, 0, 0], [128, 41, -4, 24, 0, 1]]),
# ...
